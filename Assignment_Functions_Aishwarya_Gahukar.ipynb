# %% [markdown]
# ## Assignment : Functions Assignment

# %% [markdown]
# 1. What is the difference between a function and a method in Python?

# %%
#Function: A standalone block of code defined using def that is called by its name.

#Example:
len([1, 2, 3])

#Method: A function associated with an object/class. It is called on an object using dot notation.

#Example:
"hello".upper()
# Out:
# 'HELLO'

# %%
len([1, 2, 3])
# Out:
# 3

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.

# %%
"""Parameters: The variable names listed in the function's definition.

Example: In def greet(name):, name is a parameter.

Arguments: The actual values passed to the function when it is called.

Example: In greet("Alice"), "Alice" is an argument.

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?

# %%
"""Standard Function: Defined with def, called by passing arguments in parentheses.

Example: ```python
def add(a, b): return a + b
add(2, 3)

Lambda Function: Anonymous single-expression functions.

Example: ```python
square = lambda x: x2
square(4)

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?

# %%
#Terminates the execution of a function and sends a specific value back to the caller. If no value is specified, it returns None.

#Example: ```python
def double(x): return x * 2
result = double(5)  # result gets 10

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?

# %%
"""Iterable: An object you can loop over (e.g., lists, strings). It implements __iter__().

Example: my_list = [1, 2]

Iterator: The object that actually fetches elements one by one using __next__(). It maintains a state.

Example: my_iter = iter([1, 2]); next(my_iter)

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.

# %%
"""Generators are functions that produce a sequence of values lazily using the yield keyword instead of return. They pause execution and save their state after each yield.

Example:

Python"""
def count_to_two():
    yield 1
    yield 2

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?

# %%
"""7. Advantages of Generators over Regular Functions
Memory Efficiency: Values are generated on-the-fly instead of storing an entire large list in memory.

Infinite Streams: They can represent infinite data streams safely.

Cleaner Code: Simplifies the implementation of complex custom iterators.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?

# %%
"""An anonymous, inline function limited to a single expression. Typically used as short, temporary arguments inside higher-order functions like map(), filter(), or sort().

Example:"""
multiply = lambda x, y: x * y

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python

# %%
#Applies a given function to all items in an iterable and returns an iterator map object.

#Example:
list(map(str, [1, 2, 3]))
#converts numbers to strings: ['1', '2', '3'].
# Out:
# ['1', '2', '3']

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?

# %%
"""
map(): Transforms every element in an iterable using a function.

filter(): Evaluates elements against a condition, keeping only those that return True.

reduce(): Cumulatively applies a function to sequence pairs to reduce the iterable down to a single value.

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %%
"""The reduce(lambda x, y: x + y, [47, 11, 42, 13]) function evaluates step-by-step as follows:
Step 1: Combines first two elements: $47 + 11 = 58$
Step 2: Takes previous result and next element: $58 + 42 = 100$
Step 3: Takes previous result and final element: $100 + 13 = 113$
Final output is 113. ---

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list

# %%
def sum_evens(nums):
    return sum(x for x in nums if x % 2 == 0)
sum_evens([1, 2, 3, 4, 5, 6])
# Out:
# 12

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string

# %%
def reverse_string(s):
    return s[::-1]
reverse_string("hello")
# Out:
# 'olleh'

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_list(nums):
    return [x**2 for x in nums]

square_list([1, 2, 3, 4, 5])
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 2: return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0: return False
    return True
is_prime(2)
# Out:
# True

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class Fibonacci:
    def __init__(self, terms):
        self.terms = terms
        self.count, self.a, self.b = 0, 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.terms:
            raise StopIteration
        val = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return val

fib = Fibonacci(5)
for num in fib:
    print(num)
# Out:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exp):
    for i in range(max_exp + 1):
        yield 2**i
powers_of_two(5)
for num in powers_of_two(5):
    print(num)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
with open("test.txt", "w") as f:
    f.write("Line 1\n")
    f.write("Line 2\n")
    f.write("Line 3\n")

def read_lines(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line

print("Reading from test.txt:")
for line in read_lines("test.txt"):
    print(line.strip())
# Out:
# Reading from test.txt:
# Line 1
# Line 2
# Line 3

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
data = [(1, 3), (3, 2), (2, 1)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
# Out:
# [(2, 1), (3, 2), (1, 3)]

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius = [0, 20, 30, 40]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print(fahrenheit)
# Out:
# [32.0, 68.0, 86.0, 104.0]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
text = "Hello World"
no_vowels = "".join(filter(lambda char: char.lower() not in 'aeiou', text))
print(no_vowels)
# Out:
# Hll Wrld

# %% [markdown]
# 11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
#
#
#
#
#
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = list(map(lambda x: (x[0], x[2] * x[3] if x[2] * x[3] >= 100 else x[2] * x[3] + 10), orders))
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
